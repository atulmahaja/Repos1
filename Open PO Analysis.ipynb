# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
import seaborn as sns
sns.set(font_scale=1)

# %%
order = pd.read_csv("C:\\Users\\105051884\\Desktop\\OPEN PO - PYTHON PROJECT.csv",encoding ='latin1')

# %%
order.head()
# Out:
#   Coe Responsibility Fulfillment Responsibility      SFM Name  \
# 0            ENG SYS             Shalini Khanna  Atul Mahajan
# 1            ENG SYS             Shalini Khanna  Atul Mahajan
# 2            ENG SYS             Shalini Khanna  Atul Mahajan
# 3            ENG SYS             Shalini Khanna  Atul Mahajan
# 4            ENG SYS             Shalini Khanna  Atul Mahajan
#
#                      Supplier  Supplier Code IC/EC Supplier Site Country  \
# 0  ASCO NUMATICS SIRAI S.R.L.       733318.0    EC                    IT
# 1  ASCO NUMATICS SIRAI S.R.L.       733318.0    EC                    IT
# 2  ASCO NUMATICS SIRAI S.R.L.       733318.0    EC                    IT
# 3  ASCO NUMATICS SIRAI S.R.L.       733318.0    EC                    IT
# 4  ASCO NUMATICS SIRAI S.R.L.       733318.0    EC                    IT
#
#            Supplier Email  Org Id Operations Site         ...          \
# 0  ansteam1cs@emerson.com    84.0           NP RM         ...
# ...

# %%
order= order.drop(order.columns[[5,7,8,9,10,13,17,28,40,41,42,43,58,59,61,62,63,64,65,66,71,72,73,74,77,78,81,82,83,98,99,100,101,102,103,104,105,106,107,108,109,113,114]],axis=1)

# %%
pd.set_option('display.max_columns', None)

# %%
order.head()
# Out:
#   Coe Responsibility Fulfillment Responsibility      SFM Name  \
# 0            ENG SYS             Shalini Khanna  Atul Mahajan
# 1            ENG SYS             Shalini Khanna  Atul Mahajan
# 2            ENG SYS             Shalini Khanna  Atul Mahajan
# 3            ENG SYS             Shalini Khanna  Atul Mahajan
# 4            ENG SYS             Shalini Khanna  Atul Mahajan
#
#                      Supplier  Supplier Code Supplier Site Country  \
# 0  ASCO NUMATICS SIRAI S.R.L.       733318.0                    IT
# 1  ASCO NUMATICS SIRAI S.R.L.       733318.0                    IT
# 2  ASCO NUMATICS SIRAI S.R.L.       733318.0                    IT
# 3  ASCO NUMATICS SIRAI S.R.L.       733318.0                    IT
# 4  ASCO NUMATICS SIRAI S.R.L.       733318.0                    IT
#
#   Ship to Org. Name    PO Number  PO Release  PO Line  PO Shipment  \
# 0       IO NP Massa  440229796.0         NaN      1.0          1.0
# ...

# %%
order.describe()
# Out:
#        Supplier Code     PO Number  PO Release      PO Line  PO Shipment  \
# count    1338.000000  1.338000e+03  282.000000  1338.000000  1338.000000
# mean   325607.137519  4.401791e+08  135.716312    27.642003     1.475336
# std    298895.190455  1.739836e+05   93.376582    44.879307     1.738233
# min     42329.000000  4.390969e+08    3.000000     1.000000     1.000000
# 25%    103205.000000  4.402066e+08   73.250000     2.000000     1.000000
# 50%    103437.000000  4.402337e+08   94.000000     6.000000     1.000000
# 75%    411353.000000  4.402464e+08  228.750000    35.000000     1.000000
# max    958344.000000  4.402522e+08  297.000000   229.000000    17.000000
#
#        Processing LT  Quantity Arrived  Transportation Lead Time  \
# count    1329.000000         73.000000               1338.000000
# mean       65.010534         19.026986                  7.606129
# std        47.687470         64.131428                  2.685654
# ...

# %%
order.shape
# Out:
# (1341, 75)

# %%
type(order)
# Out:
# pandas.core.indexes.base.Index

# %%
order.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-9a120f9cf80f> in <module>()
# ----> 1 order.info()
#
# AttributeError: 'Index' object has no attribute 'info'

# %%
order.isnull().any()
# Out:
# Coe Responsibility              True
# Fulfillment Responsibility      True
# SFM Name                        True
# Supplier                        True
# Supplier Code                   True
# Supplier Site Country           True
# Ship to Org. Name               True
# PO Number                       True
# PO Release                      True
# PO Line                         True
# PO Shipment                     True
# Header Approved Date            True
# Approved Date                   True
# First Approved Date             True
# Contractual Date                True
# Promised Date                   True
# Year-Quarter Promised Date      True
# Year-Month Promised Date        True
# Need By Date                    True
# Customer Want Date              True
# Buyer                           True
# Team Leader                     True
# COE                             True
# Commodity                       True
# Sub Commodity                   True
# ...

# %%
order.isnull().sum()
# Out:
# Coe Responsibility                 2
# Fulfillment Responsibility         2
# SFM Name                           3
# Supplier                           3
# Supplier Code                      3
# Supplier Site Country              3
# Ship to Org. Name                  3
# PO Number                          3
# PO Release                      1059
# PO Line                            3
# PO Shipment                        3
# Header Approved Date               3
# Approved Date                      3
# First Approved Date                3
# Contractual Date                   3
# Promised Date                      3
# Year-Quarter Promised Date         3
# Year-Month Promised Date           3
# Need By Date                       3
# Customer Want Date               954
# Buyer                              3
# Team Leader                        3
# COE                                3
# Commodity                          3
# Sub Commodity                      3
# ...

# %%
# to replace the space in the columns with the "_"
order = order.columns.str.replace(' ', '_')

# %%
type(order)
# Out:
# pandas.core.indexes.base.Index

# %%
order.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-9a120f9cf80f> in <module>()
# ----> 1 order.info()
#
# AttributeError: 'Index' object has no attribute 'info'

# %%
order.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-8b299d016653> in <module>()
# ----> 1 order.columns
#
# AttributeError: 'Index' object has no attribute 'columns'

# %%
order = list(order)

# %%
order
# Out:
# ['Coe_Responsibility',
#  'Fulfillment_Responsibility',
#  'SFM_Name',
#  'Supplier',
#  'Supplier_Code',
#  'Supplier_Site_Country',
#  'Ship_to_Org._Name',
#  'PO_Number',
#  'PO_Release',
#  'PO_Line',
#  'PO_Shipment',
#  'Header_Approved_Date',
#  'Approved_Date',
#  'First_Approved_Date',
#  'Contractual_Date_',
#  'Promised_Date',
#  'Year-Quarter_Promised_Date',
#  'Year-Month_Promised_Date',
#  'Need_By_Date_',
#  'Customer_Want_Date',
#  'Buyer',
#  'Team_Leader',
#  'COE',
#  'Commodity',
#  'Sub_Commodity',
#  'Product_Code',
#  'Product_Code_Description',
#  'Dummy_Code',
#  'Item',
#  'Item_Description',
#  'Hard/Soft',
#  'Processing_LT',
#  'Closure_Status_',
#  'Type',
#  'Quantity_Ordered',
#  'Quantity_Arrived',
#  'Currency',
#  'Unit_Price_(Po_currency)',
#  'Amount_(Po_Curr.)',
#  'Functional_Currency',
#  'Unit_Price_(Functional)',
#  'Amount_(Functional)',
#  'PO_Terms',
#  'Project_Number',
#  'Project_Name',
#  'Project_Description',
#  'New_P&L',
# ...

# %%
order.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-114-9a120f9cf80f> in <module>()
# ----> 1 order.info()
#
# AttributeError: 'list' object has no attribute 'info'

# %%
type(order)
# Out:
# list
